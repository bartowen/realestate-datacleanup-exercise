# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
df = pd.read_csv('assets/real_estate.csv', sep=';')
df
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id_realEstates', 'isNew', 'realEstate_name',
#        'phone_realEstate', 'url_inmueble', 'rooms', 'bathrooms', 'surface',
#        'price', 'date', 'description', 'address', 'country', 'level1',
#        'level2', 'level3', 'level4', 'level5', 'level6', 'level7', 'level8',
#        'upperLevel', 'countryId', 'level1Id', 'level2Id', 'level3Id',
#        'level4Id', 'level5Id', 'level6Id', 'level7Id', 'level8Id', 'accuracy',
#        'latitude', 'longitude', 'zipCode', 'customZone'],
#       dtype='object')

# %%
df_address = df['address']

df_address
# Out:
# 0        Calle Presidente Felipe Gonzalez, Arganda del Rey
# 1                         Calle Polvoranca, 6, Fuenlabrada
# 2                Calle Reyes Católicos, Boadilla del Monte
# 3                           Barrio San Andres, Fuenlabrada
# 4                                          Arganda del Rey
#                                ...
# 15330                                       Madrid Capital
# 15331                               Velilla de San Antonio
# 15332                                         Torrelodones
# 15333                               Velilla de San Antonio
# 15334              Paseo de la Castellana,  Madrid Capital
# Name: address, Length: 15335, dtype: object

# %%
# TODO

casa_mas_cara = df.sort_values('price', ascending=False).iloc[0]

direccion = casa_mas_cara['address']

precio = casa_mas_cara['price']

print(f'La casa con dirección en {direccion} es la más cara y su precio es de {precio} USD')
# Out:
# La casa con dirección en El Escorial es la más cara y su precio es de 8500000 USD

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# revisar las casa con valor = 0 USD

casas_con_precio_cero = df[df['price'] == 0]

casas_con_precio_cero

# Hay 60 casas que indican un precio 0
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 366           367       153637952  False
# 694           695       151796397  False
# 1003         1004       154000828   True
# 1255         1256       153129697  False
# 1534         1535       151708345  False
# 1554         1555       151469598  False
# 1645         1646       149639018  False
# 1798         1799       142524805  False
# 1829         1830       142524805  False
# 2049         2050       146493640  False
# 2058         2059       149127826  False
# 2197         2198       153930054  False
# 2266         2267       150007098  False
# 2750         2751       153847527  False
# 3036         3037       153170335  False
# 3201         3202       153807749  False
# 3435         3436       153993957  False
# 3959         3960       149638965  False
# 3989         3990       149638965  False
# 4019         4020       149638965  False
# 4031         4032       151708316  False
# 4167         4168       146493649  False
# ...

# %%
# se revisa solo las casas mayores a 0

df_filtrado = df[df['price'] > 0]

casa_mas_barata = df_filtrado.sort_values('price', ascending=True).iloc[0]

# Obtener la dirección y el precio
direccion = casa_mas_barata['address']
precio = casa_mas_barata['price']

# Mostrar el resultado
print(f'La casa con dirección en {direccion} es la más barata y su precio es de {precio} USD')
# Out:
# La casa con dirección en Berlin, Coslada es la más barata y su precio es de 600 USD

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15335 entries, 0 to 15334
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        15335 non-null  int64
#  1   id_realEstates    15335 non-null  int64
#  2   isNew             15335 non-null  bool
#  3   realEstate_name   15325 non-null  object
#  4   phone_realEstate  14541 non-null  float64
#  5   url_inmueble      15335 non-null  object
#  6   rooms             14982 non-null  float64
#  7   bathrooms         14990 non-null  float64
#  8   surface           14085 non-null  float64
#  9   price             15335 non-null  int64
#  10  date              15335 non-null  object
#  11  description       15193 non-null  object
#  12  address           15335 non-null  object
#  13  country           15335 non-null  object
#  14  level1            15335 non-null  object
#  15  level2            15335 non-null  object
# ...

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
# TODO

# Ordenar por superficie en orden descendente para encontrar la más grande

casa_mas_grande = df.sort_values('surface', ascending=False).iloc[0]

# Ordenar por superficie en orden ascendente para encontrar la más pequeña

casa_mas_pequena = df.sort_values('surface', ascending=True).iloc[0]

# Obtener los detalles de la casa más grande
direccion_grande = casa_mas_grande['address']
superficie_grande = casa_mas_grande['surface']
precio_grande = casa_mas_grande['price']

# Obtener los detalles de la casa más pequeña
direccion_pequena = casa_mas_pequena['address']
superficie_pequena = casa_mas_pequena['surface']
precio_pequena = casa_mas_pequena['price']

# Mostrar los resultados
print(f'La casa más grande se ubica en {direccion_grande} y tiene una superficie de {superficie_grande} m²')
print(f'La casa más pequeña se ubica en {direccion_pequena} y  tiene una superficie de {superficie_pequena} m²')
# Out:
# La casa más grande se ubica en Sevilla la Nueva y tiene una superficie de 249000.0 m²
# La casa más pequeña se ubica en Calle Amparo,  Madrid Capital y  tiene una superficie de 15.0 m²

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO

poblaciones = df['level5'].unique()

print(f'Total de poblaciones: {len(poblaciones)}')

# Imprimir las poblaciones separadas por coma
print(", ".join(poblaciones))
# Out:
# Total de poblaciones: 168
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# TODO

# Verificar si hay NAN
tiene_nas = df.isnull().values.any()

print(f' ¿Hay valores no admitidos? : {tiene_nas}')
# Out:
#  ¿Hay valores no admitidos? : True

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
df_original = df.shape

# Eliminar NaN

df_sin_nas = df.dropna()

# Guardar las nuevas dimensiones del DataFrame
dimensiones_nuevas = df_sin_nas.shape

# Imprimir la comparación de dimensiones
print(f'Dimensiones originales: {df_original}')
print(f'Dimensiones después de eliminar NAs: {dimensiones_nuevas}')
# Out:
# Dimensiones originales: (15335, 37)
# Dimensiones después de eliminar NAs: (0, 37)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# TODO

# Filtrar las filas

arroyomolinos = df[df['level5'] == "Arroyomolinos (Madrid)"]

# Calcular la media

media_precio = arroyomolinos['price'].mean()

print(f'La media de precios en Arroyomolinos (Madrid) es: {media_precio} USD')
# Out:
# La media de precios en Arroyomolinos (Madrid) es: 294541.59854014596 USD

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
# TODO: Code

import matplotlib.pyplot as plt


# Filtrar los datos para la población "Arroyomolinos (Madrid)"
arroyomolinos = df[df['level5'] == 'Arroyomolinos (Madrid)']

# Crear el histograma de precios
plt.figure(figsize=(10, 6))
plt.hist(arroyomolinos['price'], bins=30, color='skyblue', edgecolor='black')

plt.title('Histograma de precios en Arroyomolinos (Madrid)')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# La mayoría de los precios se concentra entre los 200.000 y 400.000
# Hay unos peaks altos alrededor de 300.000 y 350.000. Este podría ser el rango más frecuente.
# Presencia de outliers cercanos a 0 y mayores a 400.000 (hay que analizar estos outliers para saber si son precios exclusivos o no)

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
# TODO

# Filtrar los datos para "Valdemorillo" y "Galapagar"
valdemorillo = df[df['level5'] == 'Valdemorillo']
galapagar = df[df['level5'] == 'Galapagar']

# Calcular el precio promedio de cada población
promedio_valdemorillo = valdemorillo['price'].mean()
promedio_galapagar = galapagar['price'].mean()

# Imprimir los resultados
print(f"El precio promedio en Valdemorillo es: {promedio_valdemorillo:.2f}")
print(f"El precio promedio en Galapagar es: {promedio_galapagar:.2f}")
# Out:
# El precio promedio en Valdemorillo es: 363860.29
# El precio promedio en Galapagar es: 360063.20

# %% [markdown]
# Los promedio son muy parecidos donde VAldemorillo es mayor por 3.800

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# TODO

# Crear una nueva columna 'pps' (price per square meter)
df['pps'] = df['price'] / df['surface']

# Filtrar los datos para "Valdemorillo" y "Galapagar"
valdemorillo = df[df['level5'] == 'Valdemorillo']
galapagar = df[df['level5'] == 'Galapagar']

pps_valdemorillo = valdemorillo['pps'].mean()
pps_galapagar = galapagar['pps'].mean()

print(f"El precio promedio por metro cuadrado en Valdemorillo es: {pps_valdemorillo:.2f}")
print(f"El precio promedio por metro cuadrado en Galapagar es: {pps_galapagar:.2f}")
# Out:
# El precio promedio por metro cuadrado en Valdemorillo es: 1317.95
# El precio promedio por metro cuadrado en Galapagar es: 1606.32

# %% [markdown]
# El precio por metro cuadrado es más elevado en Galapagar pero si lo vemos como precio promedio es más barato. Esto puede ser una oportunidad de inversión, ya que se puede rentabilizar más a un menor costo.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
# TODO: Código

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='surface', y='price')

# Limitar el eje X a 1000 m²
plt.xlim(0, 1000)


plt.title('Relación entre Superficie y Precio de las Casas')
plt.xlabel('Superficie (m²)')
plt.ylabel('Precio ($)')
plt.show()

# %% [markdown]
# Se puede ver una fuerte concentración de propiedades con superficie entre 0 y 60 m2 y hay una tendencia de que los precios suben a mayor m2.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# Contar cuántas agencias de bienes raíces únicas hay en el dataset
num_agencias = df['realEstate_name'].nunique()

print(f'El dataset contiene {num_agencias} agencias de bienes raíces.')
# Out:
# El dataset contiene 1821 agencias de bienes raíces.

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# TODO

# Contar cuántas casas hay por población (level5)
poblacion_mayor_cantidad = df['level5'].value_counts().idxmax()

# Obtener el número de casas en esa población
numero_casas = df['level5'].value_counts().max()

print(f'La población con la mayor cantidad de casas es: {poblacion_mayor_cantidad}')
print(f'Número de casas en esa población: {numero_casas}')
# Out:
# La población con la mayor cantidad de casas es:  Madrid Capital
# Número de casas en esa población: 6643

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
# TODO

cinturon_sur = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']

df_sur_madrid = df[df['level5'].isin(cinturon_sur)]

df_sur_madrid.head()
# Out:
#      Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 1             2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 3             4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 85           86       153152077  False            sinergical inmobiliaria
# 94           95       153995577  False                    viviendas365com
# 109         110       153586414  False    area uno asesores inmobiliarios
#
#      phone_realEstate                                       url_inmueble  \
# 1         916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3         916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 85                NaN  https://www.fotocasa.es/es/comprar/vivienda/le...
# 94        911226014.0  https://www.fotocasa.es/es/comprar/vivienda/le...
# 109       912664081.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#      rooms  bathrooms  surface   price  ... level5Id level6Id level7Id  \
# ...

# %%
df_sur_madrid.shape
# Out:
# (907, 38)

# %%
print(f'El subconjunto tiene {len(df_sur_madrid)} registros.')
# Out:
# El subconjunto tiene 907 registros.

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# TODO: Code

mediana_precios = df_sur_madrid.groupby('level5')['price'].median().sort_values()

plt.figure(figsize=(10, 6))
mediana_precios.plot(kind='bar', color='skyblue')

plt.title('Mediana de Precios por Población (Cinturón Sur de Madrid)')
plt.xlabel('Población')
plt.ylabel('Mediana de Precio')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Getafe tiene la mediana de precios más alta, lo que sugiere que las propiedades en esa población tienden a ser más caras en comparación con las otras áreas del cinturón sur.
#
# Fuenlabrada muestra la mediana más baja, indicando que es la población con precios de viviendas más accesibles.
#
# Getafe podría tener mayor demanda o propiedades de mayor calidad, lo que impulsa los precios. Además, su cercanía a áreas clave de Madrid podría jugar un papel importante.
#
# Fuenlabrada podría ser una opción más económica, atrayendo compradores que buscan precios más accesibles.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# TODO

# Calcular la media y varianza de muestra

estadisticas = df_sur_madrid[['price', 'rooms', 'surface', 'bathrooms']].agg(['mean', 'var'])

for columna in estadisticas.columns:
    print(f'Variable: {columna}')
    print(f"Media: {estadisticas.loc['mean', columna]:.2f}")
    print(f"Varianza: {estadisticas.loc['var', columna]:.2f}")
    print('------------------')
# Out:
# Variable: price
# Media: 223094.48
# Varianza: 14921367508.05
# ------------------
# Variable: rooms
# Media: 3.02
# Varianza: 0.72
# ------------------
# Variable: surface
# Media: 111.75
# Varianza: 4263.05
# ------------------
# Variable: bathrooms
# Media: 1.63
# Varianza: 0.57
# ------------------

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# TODO

casa_mas_cara_cintu_sur = df_sur_madrid.loc[df_sur_madrid.groupby('level5')['price'].idxmax()] #idxmax: Encuentra el índice de la casa con el precio más alto en cada grupo

casa_mas_cara_cintu_sur[['level5', 'address', 'price']]
# Out:
#             level5                                address    price
# 5585      Alcorcón                               Alcorcón   950000
# 11561  Fuenlabrada  Calle de Paulo Freire, 5, Fuenlabrada   490000
# 2881        Getafe                                 Getafe  1050000
# 10412      Leganés           Avenida Reina Sofía, Leganés   650000

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
# TODO

from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# Copia df
df_normalizado = df_sur_madrid.copy()

scaler = MinMaxScaler()

# Normalizar los precios por población
df_normalizado['precio_normalizado'] = df_sur_madrid.groupby('level5')['price'].transform(
    lambda x: scaler.fit_transform(x.values.reshape(-1, 1)).flatten()
)

# Histograma
plt.figure(figsize=(12, 7))

for poblacion in df_normalizado['level5'].unique():
    subset = df_normalizado[df_normalizado['level5'] == poblacion]
    plt.hist(subset['precio_normalizado'], bins=20, alpha=0.5, label=poblacion)

plt.title('Histogramas de Precios Normalizados por Población (Cinturón Sur de Madrid)')
plt.xlabel('Precio Normalizado')
plt.ylabel('Frecuencia')
plt.legend()
plt.show()

# %% [markdown]
# Las cuatro poblaciones tienen una distribución sesgada a la derecha, lo que indica que la mayoría de las viviendas tienen precios más bajos (cerca de 0), mientras que hay pocas viviendas con precios más altos.
#
# Las viviendas más caras son excepciones (outliers)
#
# Las poblaciones como Alcorcón y Leganés muestran preciosmás bajos (cerca de 0.1 y 0.2).
#
# Getafe, muestra una distribución con una mayor frecuencia en valores más cercanos a 0.4. Esto podría indicar que los precios son más elevados en esta región y comparados con las otras regiones.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
# TODO

df_sur_madrid.loc[:, 'pps'] = df_sur_madrid['price'] / df_sur_madrid['surface']

# Verificar los primeros registros para asegurarnos de que la columna se creó correctamente
df_sur_madrid[['level5', 'price', 'surface', 'pps']].head()
# Out:
#           level5   price  surface          pps
# 1    Fuenlabrada   89000      NaN          NaN
# 3    Fuenlabrada   89000     86.0  1034.883721
# 85      Alcorcón  107000     50.0  2140.000000
# 94       Leganés  320000    120.0  2666.666667
# 109     Alcorcón  425000    142.0  2992.957746

# %%
df_sur_madrid_clean = df_sur_madrid.dropna(subset=['pps'])

# Verificar el resultado
df_sur_madrid_clean[['level5', 'price', 'surface', 'pps']].head()
# Out:
#           level5   price  surface          pps
# 3    Fuenlabrada   89000     86.0  1034.883721
# 85      Alcorcón  107000     50.0  2140.000000
# 94       Leganés  320000    120.0  2666.666667
# 109     Alcorcón  425000    142.0  2992.957746
# 161  Fuenlabrada  239500    123.0  1947.154472

# %%
# Agrupar por 'level5' y calcular la media de 'pps'
df_pps_grouped = df_sur_madrid_clean.groupby('level5')['pps'].mean()

df_pps_grouped
# Out:
# level5
# Alcorcón       2239.302480
# Fuenlabrada    1796.729220
# Getafe         2066.314949
# Leganés        2047.503268
# Name: pps, dtype: float64

# %%
# Agrupar por 'level5' y calcular la media de 'price' y 'pps'
df_price_pps_grouped = df_sur_madrid_clean.groupby('level5')[['price', 'pps']].mean()

# Ver los resultados
df_price_pps_grouped
# Out:
#                      price          pps
# level5
# Alcorcón     235453.757225  2239.302480
# Fuenlabrada  180955.426396  1796.729220
# Getafe       254106.410788  2066.314949
# Leganés      210794.375000  2047.503268

# %% [markdown]
# Según el valor por metro cuadrado, Alcorcón es más alto vs Getafe pero el valor promedio es más alto en Getafe.
#
# De todas maneras ambos municipios son los más caros del cinturón de sur

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Gráficos de dispersión en cada subgráfico
for i, municipio in enumerate(cinturon_sur):
    ax = axes[i // 2, i % 2]  # Determinar la posición del subgráfico
    df_municipio = df_sur_madrid[df_sur_madrid['level5'] == municipio]
    ax.scatter(df_municipio['surface'], df_municipio['price'], alpha=0.6)
    ax.set_title(f'Dispersión en {municipio}')
    ax.set_xlabel('Superficie (m²)')
    ax.set_ylabel('Precio')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en (60 grados latitud y -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:45, in Bunch.__getattr__(self, key)
#      44 try:
# ---> 45     return self.__getitem__(key)
#      46 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 6
#       1 from ipyleaflet import Map, basemaps
#       3 # Mapa centrado en (60 grados latitud y -2.2 grados longitud)
#       4 # Latitud, longitud
#       5 map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20,
# ----> 6     basemap=basemaps.Stamen.Terrain)
#       7 map
#
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:47, in Bunch.__getattr__(self, key)
#      45     return self.__getitem__(key)
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id_realEstates', 'isNew', 'realEstate_name',
#        'phone_realEstate', 'url_inmueble', 'rooms', 'bathrooms', 'surface',
#        'price', 'date', 'description', 'address', 'country', 'level1',
#        'level2', 'level3', 'level4', 'level5', 'level6', 'level7', 'level8',
#        'upperLevel', 'countryId', 'level1Id', 'level2Id', 'level3Id',
#        'level4Id', 'level5Id', 'level6Id', 'level7Id', 'level8Id', 'accuracy',
#        'latitude', 'longitude', 'zipCode', 'customZone', 'pps'],
#       dtype='object')

# %%
from ipyleaflet import Map, Marker, Icon
from ipywidgets import Layout

# Mapa centrado en Madrid
mapa = Map(
    center=(40.4, -3.7),
    zoom=11,
    layout=Layout(width='800px', height='500px'),
    basemap=basemaps.OpenStreetMap.Mapnik
)

# Colores para cada población
colores = {
    'Fuenlabrada': 'blue',
    'Alcorcón': 'green',
    'Leganés': 'orange',
    'Getafe': 'red'
}

# Coordenadas como lista
coordenadas = {poblacion: list(zip(grupo['latitude'], grupo['longitude']))
               for poblacion, grupo in df_sur_madrid.groupby('level5')}

# Marcadores al mapa
for poblacion, coords in coordenadas.items():
    color = colores.get(poblacion, 'gray')
    for lat, lon in coords:
        marcador = Marker(
            location=(lat, lon),
            icon=Icon(icon_color=color),
            draggable=False
        )
        mapa.add_layer(marcador)

mapa
# Out:
# Map(center=[40.4, -3.7], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out…
